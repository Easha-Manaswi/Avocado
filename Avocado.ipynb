# %%
import pandas as pd
import numpy as np
Avocado=pd.read_csv('Avo.csv')

# %%
Avocado.tail()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 1512          10  16-10-2016          1.39     190846.01  57529.11  56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87  52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75  52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79  53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41  54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 1512  17531.78    59418.46    48823.53    10354.65       240.28  conventional
# 1513  19419.57    63300.70    54704.14     8596.56         0.00  conventional
# 1514  16736.92    62415.77    53332.61     8258.16       825.00  conventional
# 1515  17495.42    63931.73    55653.47     8278.26         0.00  conventional
# 1516  16563.91    69104.56    57456.21    11648.35         0.00  conventional
#
#       year     region
# ...

# %%
Avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1           1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2           2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3           3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4           4  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
Avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
Avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   int64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   int64
#  13  region        1517 non-null   object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 166.0+ KB

# %%
Avocado.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %%
Avocado.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# Observed:
#
#  1.Date,type,region are objects
#  2.Others are float type

# %%
Avocado['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'Columbus', 'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids',
#        'GreatLakes', 'HarrisburgScranton', 'HartfordSpringfield',
#        'Houston', 'Indianapolis', 'Jacksonville', 'LasVegas',
#        'LosAngeles', 'Louisville', 'MiamiFtLauderdale', 'Midsouth',
#        'Nashville', 'NewYork', 'Northeast', 'NorthernNewEngland',
#        'Orlando', 'Philadelphia', 'PhoenixTucson', 'Pittsburgh', 'Plains',
#        'Portland', 'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
Avocado1=Avocado.drop(['year','Unnamed: 0'],axis=1)

# %%
Avocado1.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  region
# 0     8696.87     8603.62       93.25          0.0  conventional  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  Albany

# %%
Avocado1.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# std    7.579765e+05  6.474765e+05  1.182157e+05    7455.712144
# ...

# %% [markdown]
# Observed:
#
# 1.In columns Total bags,small bags,large bags 75% has maximum value
# 2.In  columns Total bags,small bags,large bags mean and std has more difference and has outliers

# %%
Avocado1.type.unique()
# Out:
# array(['conventional'], dtype=object)

# %% [markdown]
# Observed:
#
#  1.In type column are in one value hence we drop the column

# %%
Avocado=Avocado1.drop(['type'],axis=1)

# %%
Avocado
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %% [markdown]
# # Checking for missing values

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(Avocado.isnull())
plt.show()

# %% [markdown]
# Observed:
#     1.we observed that there are no null values

# %% [markdown]
# # To check the correlation

# %%
Avo=Avocado.corr()

# %%
Avo
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284
# Total Volume    0.967689    0.960642    0.910226     0.521717
# 4046            0.930395    0.922278    0.884229     0.474063
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(Avo,annot=True,cmap='winter')

# %% [markdown]
# Observed:
#     1.from above map the average price is highly correlated

# %% [markdown]
# # Data Visualiaztion

# %% [markdown]
# univariate Analysis

# %%
plt.figure(figsize=(100,50))
Avocado['AveragePrice'].plot.bar()
plt.show()

# %%
Avocado['Small Bags'].plot.hist()
plt.title('Histogram of Small Bags column')
plt.show()

# %%
Avocado['Large Bags'].plot.hist()
plt.title('Histogram of Large Bags column')
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(Avocado['Total Bags'])

# %%
plt.figure(figsize=(10,10))
sns.set(style='white')
plt.scatter(Avocado['AveragePrice'],Avocado['Total Volume'])
plt.xlabel('AveragePrice')
# Out:
# Text(0.5, 0, 'AveragePrice')

# %%
Avocado=Avocado.drop(['Date'],axis=1)

# %%
Avocado
# Out:
#       AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0             1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1             1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2             0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3             1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4             1.28      51039.60    941.48   43838.39     75.78     6183.95
# ...            ...           ...       ...        ...       ...         ...
# 1512          1.39     190846.01  57529.11   56366.66  17531.78    59418.46
# 1513          1.51     178235.75  43325.87   52189.61  19419.57    63300.70
# 1514          1.48     178410.82  46364.75   52893.38  16736.92    62415.77
# 1515          1.47     189131.52  54110.79   53593.58  17495.42    63931.73
# 1516          1.43     182978.30  43116.41   54193.42  16563.91    69104.56
#
#       Small Bags  Large Bags  XLarge Bags     region
# ...

# %%
plt.figure(figsize=(12,16))
sns.regplot(x='Total Bags',y='region',data=Avocado,fit_reg=False)
plt.show()

# %%
plt.figure(figsize=(12,16))
sns.regplot(x='Total Volume',y='region',data=Avocado,fit_reg=False)
plt.show()

# %%
plt.figure(figsize=(12,16))
sns.regplot(x='AveragePrice',y='region',data=Avocado,fit_reg=False)
plt.show()

# %% [markdown]
# # Converting

# %%
Avocado.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# region           object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Avocado['region']=le.fit_transform(Avocado['region'])

# %% [markdown]
# # To Check the Distribution of skewness

# %%
collist=Avocado.columns.values
ncol=12
nrow=10

# %%
plt.figure(figsize=(50,20))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(Avocado[collist[i]],color='blue')
    plt.tight_layout()

# %% [markdown]
# Observed:
#     1.Data is more skewed

# %%
Avocado.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# region          0.288146
# dtype: float64

# %%
for col in Avocado.columns:
    if Avocado[col].skew()>0.55:
        Avocado[col]=np.log1p(Avocado[col])

# %%
Avocado.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# region          0.288146
# dtype: float64

# %% [markdown]
# # Plotting outliers

# %%
Avocado.shape
# Out:
# (1517, 10)

# %%
Avocado['4046'].plot.box()

# %% [markdown]
# Observed:
#     1. There are no outliers

# %%
Avocado.plot(kind='box',subplots=True,layout=(2,5))
# Out:
# AveragePrice       AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Total Volume    AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# 4046             AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# 4225            AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# 4770            AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Total Bags            AxesSubplot(0.125,0.125;0.133621x0.343182)
# Small Bags         AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Large Bags          AxesSubplot(0.44569,0.125;0.133621x0.343182)
# XLarge Bags        AxesSubplot(0.606034,0.125;0.133621x0.343182)
# region             AxesSubplot(0.766379,0.125;0.133621x0.343182)
# dtype: object

# %% [markdown]
# Observed:
#     1.there are outliers in averageprice,total bags,small bags,and total baga

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore
z_score=abs(zscore(Avocado))
print(Avocado.shape)
Avo=Avocado.loc[(z_score<3).all(axis=1)]
print(Avo.shape)
# Out:
# (1517, 10)
# (1502, 10)

# %% [markdown]
# Observed:
#     1.Outliers are removed
#     2.15 rows are removed

# %% [markdown]
# # Model Training

# %%
df_x=Avocado.drop(columns=['AveragePrice'])

# %%
y=pd.DataFrame(Avocado['AveragePrice'])

# %%
df_x.head()
# Out:
#    Total Volume      4046       4225      4770  Total Bags  Small Bags  \
# 0     11.070344  6.944801  10.905146  3.895080    9.070833    9.060055
# 1     10.912867  6.515127  10.706381  4.083115    9.159737    9.149429
# 2     11.680313  6.679222  11.600485  4.879007    9.005325    8.992584
# 3     11.277116  7.032624  11.184108  4.298373    8.667708    8.644425
# 4     10.840377  6.848515  10.688288  4.340944    8.729874    8.697389
#
#    Large Bags  XLarge Bags  region
# 0    4.545951          0.0       0
# 1    4.589955          0.0       0
# 2    4.645736          0.0       0
# 3    4.903495          0.0       0
# 4    5.291746          0.0       0

# %%
y.head()
# Out:
#    AveragePrice
# 0          1.33
# 1          1.35
# 2          0.93
# 3          1.08
# 4          1.28

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.shape
# Out:
# (1517, 9)

# %%
y.shape
# Out:
# (1517, 1)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
model=Ridge()
grid=GridSearchCV(estimator=model,param_grid=alphavalue,cv=5)
grid.fit(x,y)
print(grid)
print(grid.best_estimator_.alpha)
print(grid.best_params_)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]})
# 0
# {'alpha': 0}

# %%
from sklearn import svm
svr=svm.SVR()
parameters={'kernel':['linear','rbf','poly'],'C':[1.0]}
gd=GridSearchCV(svr,parameters)
gd.fit(x,y)
sorted(gd.cv_results_.keys())
print(gd.best_params_)
# Out:
# {'C': 1.0, 'kernel': 'linear'}

# %%
max_r_score=0
for r_state in range(40,1400):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r_scr=r2_score(y_test,y_pred)
    if r_scr>max_r_score:
        max_r_score=r_scr
        final_r_state=r_state
print('max r2 score corresponding to',final_r_state,'is',max_r_score)
# Out:
# max r2 score corresponding to 1232 is 0.5034170039157699

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(kernel='linear'),Lasso(),Ridge(alpha=1),ElasticNet(),RandomForestRegressor(),AdaBoostRegressor()]
for m in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1232,test_size=.20)
    m.fit(x_train,y_train)
    print('Score of',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Error:')
    print('Mean Absolute Error :',mean_absolute_error(y_test,predm))
    print('Mean Squared Error :',mean_squared_error(y_test,predm))
    print('r2_score',r2_score(y_test,predm))
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression() is: 0.35695409708147186
# Error:
# Mean Absolute Error : 0.10325138154315137
# Mean Squared Error : 0.016527388051427616
# r2_score 0.5034170039157699
# *******************************************************************************************************
#
#
# Score of DecisionTreeRegressor() is: 1.0
# Error:
# Mean Absolute Error : 0.08013157894736843
# Mean Squared Error : 0.012913157894736843
# r2_score 0.6120104025921235
# *******************************************************************************************************
#
#
# Score of KNeighborsRegressor() is: 0.8692267989876648
# Error:
# Mean Absolute Error : 0.06573684210526314
# Mean Squared Error : 0.007874447368421049
# r2_score 0.7634038328046435
# *******************************************************************************************************
#
#
# Score of SVR(kernel='linear') is: 0.35513358009519824
# Error:
# Mean Absolute Error : 0.1032269141991942
# ...

# %%
from sklearn.model_selection import cross_val_score
for m in model:
    score=cross_val_score(m,x,y,cv=5,scoring='r2')
    print('Score of',m,'is:',score)
    print('Mean score:',score.mean())
    print('Standard deviation:',score.std())
    print('**************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression() is: [-0.06977169  0.07667088  0.38246997  0.21320767  0.1330094 ]
# Mean score: 0.14711724477151425
# Standard deviation: 0.1496404893091913
# **************************************************************************************
#
#
# Score of DecisionTreeRegressor() is: [-1.73947969 -0.47951518  0.43047232 -1.72381141  0.14764487]
# Mean score: -0.6729378194129062
# Standard deviation: 0.9132501384085097
# **************************************************************************************
#
#
# Score of KNeighborsRegressor() is: [-1.59582111 -0.42247419 -0.08841044  0.18075772  0.32413175]
# Mean score: -0.3203632538456322
# Standard deviation: 0.6866611309047553
# **************************************************************************************
#
#
# Score of SVR(kernel='linear') is: [-0.0898675   0.09907975  0.35402514  0.22383703  0.14185701]
# Mean score: 0.14578628548055497
# Standard deviation: 0.146413787183264
# ...

# %% [markdown]
# Oserved:
#     1.we have completed our project

# %%
import joblib
joblib.dump(KNeighborsRegressor,'Avocado.pkl')
# Out:
# ['Avocado.pkl']

# %% [markdown]
# Observed:
#     1.KNeighboursregressor is the best model and we get accuracy score is 60 percent
